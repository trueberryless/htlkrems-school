# %%
# MNIST 1
import tensorflow

(x_train, y_train), (x_test, y_test) = tensorflow.keras.datasets.mnist.load_data()

# 3D-Tenosr mit 60000 Samples, jeweilige Größe von 28x28 Pixel
assert x_train.shape == (60000, 28, 28)
assert x_test.shape == (10000, 28, 28)
assert y_train.shape == (60000,)
assert y_test.shape == (10000,)

import pandas as pd

## Sequential
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

model = keras.Sequential()
model.add(layers.Dense(64, activation="relu", input_shape=(784,)))
model.add(layers.Dense(10, activation="softmax"))

model.compile(optimizer="rmsprop", loss="categorical_crossentropy", metrics=["accuracy"])

model.summary()

# x_train Reshapen
x_train = x_train.reshape(60000, 784)
x_test = x_test.reshape(10000, 784)

# y_train reshapen, damit verglichen werden kann
# z.B.: [ 5 ]           -> shape: (1,)
#       [ 0000010000 ]  -> shape: (10,)

# https://keras.io/api/utils/python_utils/#to_categorical-function
# Erstellt uns in Abhängigkeit von 'num_classes' (= Anzahl der Klassen, die es im Dataset gibt => siehe alle unique 
# Antworten in y_train) einen Vektor, bei welchem jede Stelle '1' ist, die die gewünscht Ziffer (0, 1, 2, ...) repräsentiert.

from tensorflow.keras import utils
y_train = utils.to_categorical(y_train, 10)
y_test = utils.to_categorical(y_test, 10)


model_history = model.fit(x_train, y_train, epochs=32, batch_size=32, validation_data=(x_test, y_test))
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 64)                50240
#
#  dense_1 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 50,890
# Trainable params: 50,890
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/32
# 1875/1875 [==============================] - 4s 2ms/step - loss: 2.1942 - accuracy: 0.8429 - val_loss: 0.6188 - val_accuracy: 0.9084
# Epoch 2/32
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.5395 - accuracy: 0.9155 - val_loss: 0.5693 - val_accuracy: 0.9270
# Epoch 3/32
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.4600 - accuracy: 0.9280 - val_loss: 0.4652 - val_accuracy: 0.9321
# Epoch 4/32
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.4166 - accuracy: 0.9372 - val_loss: 0.6124 - val_accuracy: 0.9315
# Epoch 5/32
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3807 - accuracy: 0.9432 - val_loss: 0.6062 - val_accuracy: 0.9341
# Epoch 6/32
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3566 - accuracy: 0.9462 - val_loss: 0.4874 - val_accuracy: 0.9383
# Epoch 7/32
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3315 - accuracy: 0.9494 - val_loss: 0.5605 - val_accuracy: 0.9446
# Epoch 8/32
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3219 - accuracy: 0.9519 - val_loss: 0.5138 - val_accuracy: 0.9463
# Epoch 9/32
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2989 - accuracy: 0.9554 - val_loss: 0.5598 - val_accuracy: 0.9473
# Epoch 10/32
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2945 - accuracy: 0.9560 - val_loss: 0.5706 - val_accuracy: 0.9491
# Epoch 11/32
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2979 - accuracy: 0.9576 - val_loss: 0.5006 - val_accuracy: 0.9446
# Epoch 12/32
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2779 - accuracy: 0.9579 - val_loss: 0.6664 - val_accuracy: 0.9440
# Epoch 13/32
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2636 - accuracy: 0.9599 - val_loss: 0.5952 - val_accuracy: 0.9438
# Epoch 14/32
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2596 - accuracy: 0.9616 - val_loss: 0.5992 - val_accuracy: 0.9445
# Epoch 15/32
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2578 - accuracy: 0.9614 - val_loss: 0.5929 - val_accuracy: 0.9443
# Epoch 16/32
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2490 - accuracy: 0.9633 - val_loss: 0.6704 - val_accuracy: 0.9510
# Epoch 17/32
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2399 - accuracy: 0.9635 - val_loss: 0.6309 - val_accuracy: 0.9455
# Epoch 18/32
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2419 - accuracy: 0.9645 - val_loss: 0.6461 - val_accuracy: 0.9504
# Epoch 19/32
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2414 - accuracy: 0.9660 - val_loss: 0.7181 - val_accuracy: 0.9472
# Epoch 20/32
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2341 - accuracy: 0.9665 - val_loss: 0.6289 - val_accuracy: 0.9523
# Epoch 21/32
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2179 - accuracy: 0.9677 - val_loss: 0.6493 - val_accuracy: 0.9468
# Epoch 22/32
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2177 - accuracy: 0.9675 - val_loss: 0.7062 - val_accuracy: 0.9520
# Epoch 23/32
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2212 - accuracy: 0.9684 - val_loss: 0.7112 - val_accuracy: 0.9571
# Epoch 24/32
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2167 - accuracy: 0.9692 - val_loss: 0.6596 - val_accuracy: 0.9563
# Epoch 25/32
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2113 - accuracy: 0.9694 - val_loss: 0.6216 - val_accuracy: 0.9528
# Epoch 26/32
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2096 - accuracy: 0.9706 - val_loss: 0.7194 - val_accuracy: 0.9539
# Epoch 27/32
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1984 - accuracy: 0.9705 - val_loss: 0.6974 - val_accuracy: 0.9544
# Epoch 28/32
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2029 - accuracy: 0.9710 - val_loss: 0.7193 - val_accuracy: 0.9552
# Epoch 29/32
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1950 - accuracy: 0.9717 - val_loss: 0.7070 - val_accuracy: 0.9494
# Epoch 30/32
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1928 - accuracy: 0.9724 - val_loss: 0.7493 - val_accuracy: 0.9558
# Epoch 31/32
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.1824 - accuracy: 0.9718 - val_loss: 0.7360 - val_accuracy: 0.9549
# Epoch 32/32
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1871 - accuracy: 0.9727 - val_loss: 0.7716 - val_accuracy: 0.9495

# %%
acc = model_history.history["accuracy"]
acc
# Out:
# [0.8429166674613953,
#  0.9154833555221558,
#  0.9280166625976562,
#  0.9372166395187378,
#  0.9431999921798706,
#  0.9461666941642761,
#  0.949400007724762,
#  0.9518833160400391,
#  0.9554333090782166,
#  0.9559999704360962,
#  0.9575666785240173,
#  0.9578999876976013,
#  0.9598666429519653,
#  0.961566686630249,
#  0.9613833427429199,
#  0.9633333086967468,
#  0.9634833335876465,
#  0.9645166397094727,
#  0.9660166501998901,
#  0.9664999842643738,
#  0.9676833152770996,
#  0.9674666523933411,
#  0.9684000015258789,
#  0.9692333340644836,
#  0.9694166779518127,
#  0.9705666899681091,
#  0.970466673374176,
#  0.9710333347320557,
#  0.9717000126838684,
#  0.9724166393280029,
#  0.9718166589736938,
#  0.9727333188056946]

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.plot(np.arange(1, len(acc) + 1), acc, 'b', label="Training")
plt.title("Korrektklassifizierungsrate Training")
plt.xlabel("Epochen")
plt.ylabel("Korrektklassifizierungsrate")
plt.legend()
plt.show()

# %%
loss = model_history.history["loss"]
loss
# Out:
# [2.1942458152770996,
#  0.539505124092102,
#  0.4599764943122864,
#  0.41662952303886414,
#  0.3807363510131836,
#  0.3565652370452881,
#  0.331510990858078,
#  0.3218582272529602,
#  0.2989406883716583,
#  0.2945152521133423,
#  0.297855406999588,
#  0.27793851494789124,
#  0.2636300027370453,
#  0.2595902383327484,
#  0.25778475403785706,
#  0.24899598956108093,
#  0.2399466633796692,
#  0.2418913096189499,
#  0.24142277240753174,
#  0.2340955287218094,
#  0.21786800026893616,
#  0.2177051305770874,
#  0.22120080888271332,
#  0.21669238805770874,
#  0.21131673455238342,
#  0.20961779356002808,
#  0.19843854010105133,
#  0.2029334008693695,
#  0.19495224952697754,
#  0.19282668828964233,
#  0.1824069619178772,
#  0.18711522221565247]

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.plot(np.arange(1, len(loss) + 1), loss, 'b', label="Loss")
plt.title("Losses")
plt.xlabel("Epochen")
plt.ylabel("Loss Rate")
plt.legend()
plt.show()

# %%
val_acc = model_history.history["val_accuracy"]
val_acc
# Out:
# [0.9083999991416931,
#  0.9269999861717224,
#  0.9320999979972839,
#  0.9315000176429749,
#  0.9340999722480774,
#  0.9383000135421753,
#  0.944599986076355,
#  0.9463000297546387,
#  0.9473000168800354,
#  0.9491000175476074,
#  0.944599986076355,
#  0.9440000057220459,
#  0.9437999725341797,
#  0.9445000290870667,
#  0.9442999958992004,
#  0.9509999752044678,
#  0.9455000162124634,
#  0.9503999948501587,
#  0.9472000002861023,
#  0.9523000121116638,
#  0.9467999935150146,
#  0.9520000219345093,
#  0.957099974155426,
#  0.9563000202178955,
#  0.9527999758720398,
#  0.9538999795913696,
#  0.9544000029563904,
#  0.9552000164985657,
#  0.949400007724762,
#  0.9557999968528748,
#  0.9549000263214111,
#  0.9495000243186951]

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.plot(np.arange(1, len(acc) + 1), acc, 'b', label="Accuracy")
plt.plot(np.arange(1, len(val_acc) + 1), val_acc, 'r', label="Value Accuracy")
plt.ylim(0.90,1)

plt.title("Losses")
plt.xlabel("Epochen")
plt.ylabel("Loss Rate")
plt.legend()
plt.show()

# %%
model.save('./model.h5')
